# %%
import load_data
import seaborn
import matplotlib.pyplot as plt

# %%
df = load_data.get()

# %%
seaborn.countplot(data=df[df["properties_build_year"] != -1], y="properties_build_year")
plt.savefig('../year-distributions.pdf')
